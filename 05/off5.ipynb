# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_data=pd.read_csv('./train.csv')
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_data.shape
# Out:
# (891, 12)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
train_data['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
train_data.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_data.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
train_data.dropna(subset=['Age'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_data.fillna(train_data.mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
train_data['Age'].mean()
# Out:
# 29.69911764705882

# %%
train_data['Age'].fillna(train_data['Age'].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df = pd.read_csv('./train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
class_group = df.groupby('Pclass')
class_group

# %%
class_group.groups
# Out:
# {1: Int64Index([  1,   3,   6,  11,  23,  27,  30,  31,  34,  35,
#              ...
#              853, 856, 857, 862, 867, 871, 872, 879, 887, 889],
#             dtype='int64', length=216),
#  2: Int64Index([  9,  15,  17,  20,  21,  33,  41,  43,  53,  56,
#              ...
#              848, 854, 861, 864, 865, 866, 874, 880, 883, 886],
#             dtype='int64', length=184),
#  3: Int64Index([  0,   2,   4,   5,   7,   8,  10,  12,  13,  14,
#              ...
#              875, 876, 877, 878, 881, 882, 884, 885, 888, 890],
#             dtype='int64', length=491)}

# %%
class_group.count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %%
class_group.sum()
# Out:
#         PassengerId  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1             99705       136  7111.42     90     77  18177.4125
# 2             82056        87  5168.83     74     70   3801.8417
# 3            215625       119  8924.92    302    193   6714.6951

# %%
class_group.mean()
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
class_group.mean()['Survived']
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
df.groupby('Sex').mean()
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
df.groupby('Sex').mean()['Survived']
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
cg_group = df.groupby(['Pclass','Sex']).mean()
cg_group
# Out:
#                PassengerId  Survived        Age     SibSp     Parch  \
# Pclass Sex
# 1      female   469.212766  0.968085  34.611765  0.553191  0.457447
#        male     455.729508  0.368852  41.281386  0.311475  0.278689
# 2      female   443.105263  0.921053  28.722973  0.486842  0.605263
#        male     447.962963  0.157407  30.740707  0.342593  0.222222
# 3      female   399.729167  0.500000  21.750000  0.895833  0.798611
#        male     455.515850  0.135447  26.507589  0.498559  0.224784
#
#                      Fare
# Pclass Sex
# 1      female  106.125798
#        male     67.226127
# 2      female   21.970121
#        male     19.741782
# 3      female   16.118810
#        male     12.661633

# %%
cg_group.index
# Out:
# MultiIndex([(1, 'female'),
#             (1,   'male'),
#             (2, 'female'),
#             (2,   'male'),
#             (3, 'female'),
#             (3,   'male')],
#            names=['Pclass', 'Sex'])

# %%
cg_group['Survived']
# Out:
# Pclass  Sex
# 1       female    0.968085
#         male      0.368852
# 2       female    0.921053
#         male      0.157407
# 3       female    0.500000
#         male      0.135447
# Name: Survived, dtype: float64

# %%
cg_group.loc[(2,'female')]
# Out:
# PassengerId    443.105263
# Survived         0.921053
# Age             28.722973
# SibSp            0.486842
# Parch            0.605263
# Fare            21.970121
# Name: (2, female), dtype: float64

# %%
retail = pd.read_csv('./OnlineRetail.csv')
retail
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
retail.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
retail.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
retail.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
retail.isnull()
# Out:
#         InvoiceNo  StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# 0           False      False        False     False        False      False
# 1           False      False        False     False        False      False
# 2           False      False        False     False        False      False
# 3           False      False        False     False        False      False
# 4           False      False        False     False        False      False
# ...           ...        ...          ...       ...          ...        ...
# 541904      False      False        False     False        False      False
# 541905      False      False        False     False        False      False
# 541906      False      False        False     False        False      False
# 541907      False      False        False     False        False      False
# 541908      False      False        False     False        False      False
#
#         CustomerID  Country
# ...

# %%
retail.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
retail.dropna(subset=['CustomerID'])
retail
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
retail[retail["Quantity"]>0]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
retail
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
retail = retail[retail['Quantity']>0]
retail = retail[retail['UnitPrice']>0]

retail
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
retail[(retail['Quantity']>0) & (retail['UnitPrice']>0)]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 530104 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    530104 non-null  object
#  1   StockCode    530104 non-null  object
#  2   Description  530104 non-null  object
#  3   Quantity     530104 non-null  int64
#  4   InvoiceDate  530104 non-null  object
#  5   UnitPrice    530104 non-null  float64
#  6   CustomerID   397884 non-null  float64
#  7   Country      530104 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 36.4+ MB

# %%
retail.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  530104.000000  530104.000000  397884.000000
# mean       10.542037       3.907625   15294.423453
# std       155.524124      35.915681    1713.141560
# min         1.000000       0.001000   12346.000000
# 25%         1.000000       1.250000   13969.000000
# 50%         3.000000       2.080000   15159.000000
# 75%        10.000000       4.130000   16795.000000
# max     80995.000000   13541.330000   18287.000000

# %%
retail.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
retail['CehckoutPrice'] = retail['UnitPrice'] * retail['Quantity']
retail.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  CehckoutPrice
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom          15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom          20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom          22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom          20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom          20.34

# %%
retail.to_csv('./OnlineRetailClean.csv')

# %%
retail = pd.read_csv('./OnlineRetailClean.csv')
retail.head()
# Out:
# /Users/pangwoon/miniconda3/envs/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  Unnamed: 0.1 InvoiceNo StockCode  \
# 0           0             0    536365    85123A
# 1           1             1    536365     71053
# 2           2             2    536365    84406B
# 3           3             3    536365    84029G
# 4           4             4    536365    84029E
#
#                            Description  Quantity          InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6  2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6  2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8  2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6  2010-12-01 08:26:00
# ...

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530104 entries, 0 to 530103
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     530104 non-null  int64
#  1   Unnamed: 0.1   530104 non-null  int64
#  2   InvoiceNo      530104 non-null  object
#  3   StockCode      530104 non-null  object
#  4   Description    530104 non-null  object
#  5   Quantity       530104 non-null  int64
#  6   InvoiceDate    530104 non-null  object
#  7   UnitPrice      530104 non-null  float64
#  8   CustomerID     397884 non-null  float64
#  9   Country        530104 non-null  object
#  10  CheckoutPrice  530104 non-null  float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 44.5+ MB

# %%
retail['InvoiceDate'] = pd.to_datetime(retail['InvoiceDate'], infer_datetime_format=True)
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530104 entries, 0 to 530103
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         530104 non-null  int64
#  1   Unnamed: 0.1       530104 non-null  int64
#  2   InvoiceNo          530104 non-null  object
#  3   StockCode          530104 non-null  object
#  4   Description        530104 non-null  object
#  5   Quantity           530104 non-null  int64
#  6   InvoiceDate        530104 non-null  datetime64[ns]
#  7   UnitPrice          530104 non-null  float64
#  8   CustomerID         397884 non-null  float64
#  9   Country            530104 non-null  object
#  10  CheckoutPrice      530104 non-null  float64
#  11  InvoiceDate_month  530104 non-null  object
#  12  InvoiceDate_dow    530104 non-null  int64
#  13  InvoiceDate_hour   530104 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(5), object(5)
# ...

# %%
total_revenue = retail['CheckoutPrice'].sum()
total_revenue
# Out:
# 10666684.544

# %%
retail.groupby('Country').sum()
# Out:
#                         Unnamed: 0  Unnamed: 0.1  Quantity     UnitPrice  \
# Country
# Australia                259111431     265381714     83901  3.612500e+03
# Austria                  115515513     118301156      4881  1.693900e+03
# Bahrain                    3105456       3182701       314  8.276000e+01
# Belgium                  548729509     561892335     23237  7.372850e+03
# Brazil                     4909456       5034064       356  1.426000e+02
# Canada                    35460309      36331486      2763  9.105800e+02
# Channel Islands          186351517     190820428      9491  3.389650e+03
# Cyprus                   141969701     145370145      6361  3.506180e+03
# Czech Republic             5263145       5389080       671  7.827000e+01
# Denmark                  111190046     113827769      8235  1.195550e+03
# EIRE                    2206077555    2258854908    147173  3.848995e+04
# European Community        13706110      14044599       499  2.898000e+02
# ...

# %%
retail.groupby('Country').sum()['CheckoutPrice'].sort_values()
# Out:
# Country
# Saudi Arabia            1.459200e+02
# Bahrain                 7.541400e+02
# Czech Republic          8.267400e+02
# RSA                     1.002310e+03
# Brazil                  1.143600e+03
# European Community      1.300250e+03
# Lithuania               1.661060e+03
# Lebanon                 1.693880e+03
# United Arab Emirates    1.902280e+03
# Malta                   2.725590e+03
# USA                     3.580390e+03
# Canada                  3.666380e+03
# Iceland                 4.310000e+03
# Unspecified             4.749790e+03
# Greece                  4.760520e+03
# Poland                  7.334650e+03
# Israel                  8.135260e+03
# Austria                 1.019868e+04
# Cyprus                  1.359038e+04
# Hong Kong               1.569180e+04
# Italy                   1.748324e+04
# Denmark                 1.895534e+04
# Channel Islands         2.045044e+04
# Singapore               2.127929e+04
# Finland                 2.254608e+04
# ...

# %%
rev_by_countries = retail.groupby('Country').sum()['CheckoutPrice'].sort_values()

# %%
plt.figure(figsize=(20,10))
plt.bar(rev_by_countries.index, rev_by_countries.values, tick_label=rev_by_countries.index)
plt.xlabel('Country', fontsize=11)
plt.ylabel('Revenue', fontsize=11)
plt.title('Revenue by Countries', fontsize=13)
plt.xticks(rotation=90)
plt.show()

# %%
rev_by_countries / total_revenue
# Out:
# Country
# Saudi Arabia            0.000014
# Bahrain                 0.000071
# Czech Republic          0.000078
# RSA                     0.000094
# Brazil                  0.000107
# European Community      0.000122
# Lithuania               0.000156
# Lebanon                 0.000159
# United Arab Emirates    0.000178
# Malta                   0.000256
# USA                     0.000336
# Canada                  0.000344
# Iceland                 0.000404
# Unspecified             0.000445
# Greece                  0.000446
# Poland                  0.000688
# Israel                  0.000763
# Austria                 0.000956
# Cyprus                  0.001274
# Hong Kong               0.001471
# Italy                   0.001639
# Denmark                 0.001777
# Channel Islands         0.001917
# Singapore               0.001995
# Finland                 0.002114
# Portugal                0.003164
# Norway                  0.003391
# Japan                   0.003508
# ...

# %%
retail.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 InvoiceNo StockCode  \
# 0           0             0    536365    85123A
# 1           1             1    536365     71053
# 2           2             2    536365    84406B
# 3           3             3    536365    84029G
# 4           4             4    536365    84029E
#
#                            Description  Quantity         InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  CheckoutPrice InvoiceDate_month  \
# 0       2.55     17850.0  United Kingdom          15.30            201012
# 1       3.39     17850.0  United Kingdom          20.34            201012
# ...

# %%
retail['InvoiceDate'].sort_values(ascending=True)  # 내림차순 정렬
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 530091   2011-12-09 12:50:00
# 530090   2011-12-09 12:50:00
# 530102   2011-12-09 12:50:00
# 530095   2011-12-09 12:50:00
# 530103   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 530104, dtype: datetime64[ns]

# %%
retail['InvoiceDate']
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 530099   2011-12-09 12:50:00
# 530100   2011-12-09 12:50:00
# 530101   2011-12-09 12:50:00
# 530102   2011-12-09 12:50:00
# 530103   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 530104, dtype: datetime64[ns]

# %%
retail['InvoiceDate'][0]
# Out:
# Timestamp('2010-12-01 08:26:00')

# %%
month=[]
dow=[]
hour=[]

for i in range(len(retail['InvoiceDate'])):
    if retail['InvoiceDate'][i].month<10:
        month.append(str(retail['InvoiceDate'][i].year) + '0' + str(retail['InvoiceDate'][i].month))
    else:
        month.append(str(retail['InvoiceDate'][i].year) + str(retail['InvoiceDate'][i].month))
    
    dow.append(retail['InvoiceDate'][i].dayofweek)
    hour.append(retail['InvoiceDate'][i].hour)

# %%
len(month)
# Out:
# 530104

# %%
retail['InvoiceDate_month'] = month
retail['InvoiceDate_dow'] = dow
retail['InvoiceDate_hour'] = hour

retail
# Out:
#         Unnamed: 0  Unnamed: 0.1 InvoiceNo StockCode  \
# 0                0             0    536365    85123A
# 1                1             1    536365     71053
# 2                2             2    536365    84406B
# 3                3             3    536365    84029G
# 4                4             4    536365    84029E
# ...            ...           ...       ...       ...
# 530099      530099        541904    581587     22613
# 530100      530100        541905    581587     22899
# 530101      530101        541906    581587     23254
# 530102      530102        541907    581587     23255
# 530103      530103        541908    581587     22138
#
#                                 Description  Quantity         InvoiceDate  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                       WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2            CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# ...

# %%
rev_by_month = retail.groupby('InvoiceDate_month').sum()['CheckoutPrice']
rev_by_month
# Out:
# InvoiceDate_month
# 201012     823746.140
# 201101     691364.560
# 201102     523631.890
# 201103     717639.360
# 201104     537808.621
# 201105     770536.020
# 201106     761739.900
# 201107     719221.191
# 201108     759138.380
# 201109    1058590.172
# 201110    1154979.300
# 201111    1509496.330
# 201112     638792.680
# Name: CheckoutPrice, dtype: float64

# %%
plt.figure(figsize=(20,10))
plt.bar(rev_by_month.index, rev_by_month.values, tick_label=rev_by_month.index)
plt.xlabel('Month', fontsize=11)
plt.ylabel('Revenue', fontsize=11)
plt.title('Revenue by month', fontsize=13)
plt.xticks(rotation=45)
plt.show()

# %%
rev_by_dow = retail.groupby('InvoiceDate_dow').sum()
rev_by_dow
# Out:
#                   Unnamed: 0  Unnamed: 0.1  Quantity   UnitPrice  \
# InvoiceDate_dow
# 0                24305754614   24883611855    873332  399563.341
# 1                26165535950   26788851155   1115208  421157.651
# 2                24287723232   24866434909   1027431  353376.140
# 3                26867540261   27507376917   1209617  382087.020
# 4                21046566848   21548438587    891784  332308.021
# 6                17831739451   18257332580    471004  182955.601
#
#                    CustomerID  CheckoutPrice  InvoiceDate_hour
# InvoiceDate_dow
# 0                9.916745e+08    1779575.041           1217807
# 1                1.015707e+09    2178632.611           1309510
# 2                1.054491e+09    1851147.810           1206708
# 3                1.222015e+09    2203161.240           1357131
# 4                8.315951e+08    1840340.231           1012779
# 6                9.699240e+08     813827.611            827505

# %%
rev_by_dow = retail.groupby('InvoiceDate_dow').sum()['CheckoutPrice']
rev_by_dow
# Out:
# InvoiceDate_dow
# 0    1779575.041
# 1    2178632.611
# 2    1851147.810
# 3    2203161.240
# 4    1840340.231
# 6     813827.611
# Name: CheckoutPrice, dtype: float64

# %%
DAY_OF_WEEK = np.array(['Mon','Tue','Wed','Thur','Fri','Sat','Sun'])
rev_by_dow.index = DAY_OF_WEEK[rev_by_dow.index]

# %%
plt.figure(figsize=(20,10))
plt.bar(rev_by_dow.index, rev_by_dow.values, tick_label=rev_by_dow.index)
plt.xlabel('DoW', fontsize=11)
plt.ylabel('Revenue', fontsize=11)
plt.title('Revenue by DoW', fontsize=13)
plt.show()

# %%
retail.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 InvoiceNo StockCode  \
# 0           0             0    536365    85123A
# 1           1             1    536365     71053
# 2           2             2    536365    84406B
# 3           3             3    536365    84029G
# 4           4             4    536365    84029E
#
#                            Description  Quantity         InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  CheckoutPrice InvoiceDate_month  \
# 0       2.55     17850.0  United Kingdom          15.30            201012
# 1       3.39     17850.0  United Kingdom          20.34            201012
# ...

# %%
rev_by_hour = retail.groupby('InvoiceDate_hour').sum()['CheckoutPrice']
rev_by_hour
# Out:
# InvoiceDate_hour
# 6           4.250
# 7       31059.210
# 8      283868.520
# 9      990267.821
# 10    1446742.701
# 11    1239954.440
# 12    1444245.880
# 13    1265736.300
# 14    1181812.371
# 15    1352972.180
# 16     754006.560
# 17     461603.491
# 18     144813.050
# 19      50665.010
# 20      18932.760
# Name: CheckoutPrice, dtype: float64

# %%
plt.figure(figsize=(20,10))
plt.bar(rev_by_hour.index, rev_by_hour.values, tick_label=rev_by_hour.index)
plt.xlabel('Hour', fontsize=11)
plt.ylabel('Revenue', fontsize=11)
plt.title('Revenue by Hour', fontsize=13)
plt.show()

# %%
retail.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 InvoiceNo StockCode  \
# 0           0             0    536365    85123A
# 1           1             1    536365     71053
# 2           2             2    536365    84406B
# 3           3             3    536365    84029G
# 4           4             4    536365    84029E
#
#                            Description  Quantity         InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  CheckoutPrice InvoiceDate_month  \
# 0       2.55     17850.0  United Kingdom          15.30            201012
# 1       3.39     17850.0  United Kingdom          20.34            201012
# ...

# %%
top_selling = retail.groupby('StockCode').sum()
top_selling
# Out:
#               Unnamed: 0  Unnamed: 0.1  Quantity  UnitPrice  CustomerID  \
# StockCode
# 10002            4128457       4225856       860      77.15    723842.0
# 10080            7486576       7665869       303       9.04    333014.0
# 10120            8192630       8386616       193       6.30    484879.0
# 10123C            249979        255991         5       1.95     46701.0
# 10124A            780417        798896        16       2.10     81148.0
# ...                  ...           ...       ...        ...         ...
# gift_0001_20     1671981       1712910        10     150.38         0.0
# gift_0001_30     1346444       1379326         7     175.53         0.0
# gift_0001_40      453676        464719         3     100.70         0.0
# gift_0001_50      688749        705873         4     167.56         0.0
# m                  39476         40383         1       2.55         0.0
#
#               CheckoutPrice  InvoiceDate_dow  InvoiceDate_hour
# StockCode
# ...

# %%
top_selling = retail.groupby('StockCode').sum()['Quantity'].sort_values(ascending=False)
top_selling
# Out:
# StockCode
# 23843     80995
# 23166     78033
# 22197     56921
# 84077     55047
# 85099B    48474
#           ...
# 82613a        1
# 84031a        1
# 84031b        1
# 21160         1
# m             1
# Name: Quantity, Length: 3922, dtype: int64

# %%
top_selling = retail.groupby('StockCode').sum()['Quantity'].sort_values(ascending=False)[:3]
top_selling
# Out:
# StockCode
# 23843    80995
# 23166    78033
# 22197    56921
# Name: Quantity, dtype: int64

# %%
top_revenue = retail.groupby('StockCode').sum()['CheckoutPrice'].sort_values(ascending=False)[:10]
top_revenue
# Out:
# StockCode
# DOT       206248.77
# 22423     174484.74
# 23843     168469.60
# 85123A    104518.80
# 47566      99504.33
# 85099B     94340.05
# 23166      81700.92
# M          78110.27
# POST       78101.88
# 23084      66964.99
# Name: CheckoutPrice, dtype: float64

# %%
retail.groupby('StockCode')['CheckoutPrice'].sum().sort_values(ascending=False)[:10]
# Out:
# StockCode
# DOT       206248.77
# 22423     174484.74
# 23843     168469.60
# 85123A    104518.80
# 47566      99504.33
# 85099B     94340.05
# 23166      81700.92
# M          78110.27
# POST       78101.88
# 23084      66964.99
# Name: CheckoutPrice, dtype: float64
